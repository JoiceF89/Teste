# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(1) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/05/1971-dom-paulo-evaristo-arns-sofre-acidente-automobilistico-em-sc.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo1 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo1[titulo] = artigo

print(conteudo1)
# Out:
# {'    1971: Dom Paulo Evaristo Arns sofre acidente automobilístico em SC  ': 'O arcebispo de São Paulo, dom Paulo Evaristo Arns, teve fratura exposta no tornozelo e escoriações na cabeça, ao sofrer um acidente automobilístico, em Santa Catarina, nesta sexta-feira (14). Segundo os médicos, seu estado de saúde é bom.O carro, que era dirigido pelo irmão marista Antonio Poeing, capotou na rodovia BR-101 após tentar desviar de uma pedra na pista.A mãe de dom Paulo, Helena, e as irmãs dele Zilda e Ida também estavam no automóvel.Eles iam para Forquilhinha, terra natal do arcebispo, para assistir a uma cerimônia religiosa.      Primeira Página da Folha de 15 de maio de 1971             - Reprodução'}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(2) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/02/1971-chuvas-provocam-22-mortes-em-sao-paulo-no-abc-e-na-baixada-santista.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo2 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace('\n', ' ').replace('\r', '').replace('  ', '').replace('Primeira Página da Folha de', '').replace('- Reprodução', '')

conteudo2[titulo] = artigo

print(conteudo2)
# Out:
# {'    1971: Chuvas provocam 22 mortes em São Paulo, no ABC e na Baixada Santista  ': ' As chuvas que durante dois dias caíram no estado de São Paulo provocaram 22 mortes na capital, na região do ABC e na Baixada Santista. Na cidade de São Paulo, a Companhia de Gás, cuja rede foi intensamente afetada pelas águas, informou que a distribuição de gás deverá ser normalizada até as 12 deste sábado (27). A Companhia Telefônica, porém, só poderá iniciar o conserto de 5.000 telefones emudecidos quando as águas baixarem nas galerias inundadas. A Guanabara também sofreu com as chuvas. Extraoficialmente, já fala-se em 30 mortos. No estado do Rio de Janeiro, o número seria de 50.  27 de fevereiro de 1971 '}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(3) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/02/1971-petrobras-intensifica-pesquisas-no-mar-e-contrata-2-navios-sonda.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo3 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo3[titulo] = artigo

print(conteudo3)
# Out:
# {'    1971: Petrobras intensifica pesquisas no mar e contrata 2 navios-sonda  ': 'A Petrobras contratou dois navios-sonda, um vai operar no litoral norte do Paraná e outro atuará em Sergipe.O consumo brasileiro de petróleo é atualmente de 500 mil barris por dia, dos quais 170 mil são extraídos no país. O restante é importado.Os técnicos aguardam notícias mais concretas sobre a capacidade de produção do campo de Caioba, descoberto a 12 quilômetros de Aracaju (SE) pela plataforma de fabricação nacional “Petrobras-1”. Mas o clima é de euforia com o primeiro poço perfurado.O navio-sonda que agora foi contratado para Sergipe vai operar nos campos de Dourado e de Guaricema.      Primeira Página da Folha de 13 de fevereiro de 1971             - Reprodução'}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(4) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/04/1971-apos-soltar-tenente-nixon-estudara-condenacao-por-massacre-de-my-lai.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo4 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo4[titulo] = artigo

print(conteudo4)
# Out:
# {'    1971: Após soltar tenente, Nixon estudará condenação por massacre de My Lai  ': 'Depois de ter mandado soltar o tenente William Calley (condenado à prisão perpétua pela Corte Marcial pelo assassinato de 22 civis em My Lai, no Vietnã do Sul), o presidente dos Estados Unidos, Richard Nixon, “revisará pessoalmente o caso”, informou a Casa Branca.Conforme o divulgado, essa revisão será feita “antes que a sentença seja acolhida em qualquer etapa de seu processo de apelação”.O Exército, por sua vez, rompeu o silêncio sobre a condenação e publicou um documento no qual afirma que tinha o dever de investigar a matança em My Lai.William Calley está em liberdade vigiada.      Primeira Página da Folha de 4 de abril de 1971             - Reprodução'}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(5) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/02/1971-ingleses-propoem-que-nobel-da-paz-seja-entregue-aos-irmaos-villas-boas.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo5 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo5[titulo] = artigo

print(conteudo5)
# Out:
# {'    1971: Ingleses propõem que Nobel da Paz seja entregue aos irmãos Villas Bôas  ': 'Os 28 anos de trabalhos dedicados aos índios poderão dar aos irmãos Orlando e Claudio Villas Bôas o Prêmio Nobel da Paz deste ano. A indicação dos nomes dos sertanistas brasileiros foi feita pela Fundação dos Povos Primitivos, com sede em Londres.Durante esses anos, os irmãos enfrentaram muitos perigos nas matas para tentar garantir aos índios o direito de evoluir naturalmente, mantendo a cultura, costumes e tradições.Orlando disse estar honrado com a indicação. “O que se pretende é prestigiar alguém que simbolize o movimento humanístico de assistência aos índios”, declarou.      Primeira Página da Folha de 14 de fevereiro de 1971             - Reprodução'}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(6) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/02/1971-brasil-lidera-batalha-para-evitar-que-preco-do-cafe-continue-em-queda.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo6 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo6[titulo] = artigo

print(conteudo6)
# Out:
# {'    1971: Brasil lidera batalha para evitar que preço do café continue em queda  ': 'O Brasil abre nesta segunda-feira (8) a grande batalha para impedir que os preços do café no mercado internacional continuem a sofrer uma baixa desastrosa.Em Londres, o presidente do Instituto Brasileiro do Café, Mario Penteado de Faria e Silva, reunirá os principais produtores de café da América Latina para novamente procurar uma frente comum diante das exigências dos países consumidores, liderados pelos Estados Unidos.Para tentar estimular um nível melhor de preços, o Brasil pedirá que sejam reduzidas as cotas de exportação fixadas pelo Acordo Internacional do Café.       Primeira Página da Folha de 8 de fevereiro de 1971             - Reprodução'}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(7) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/02/1971-campeonato-nacional-de-futebol-vai-substituir-o-velho-robertao.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo7 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo7[titulo] = artigo

print(conteudo7)
# Out:
# {'    1971: Campeonato Nacional de Futebol vai substituir o velho Robertão  ': 'A CBD (Confederação Brasileira de Desportos) aprovou nesta quarta-feira (4) as diretrizes para a realização do Campeonato Nacional de Futebol Profissional.Com isso, o Torneio Roberto Gomes Pedrosa, o Robertão, não será mais disputado.O Campeonato Nacional está previsto para começar a partir de agosto, com 20 clubes (dos estados de São Paulo, Guanabara, Minas Gerais, Rio Grande do Sul, Pernambuco, Bahia, Paraná e Ceará).Para estabelecer as bases da nova competição, a confederação considerou as cidades em que todas as partidas serão disputadas levando em conta os estádios.      Primeira Página da Folha de 5 de fevereiro de 1971             - Reprodução'}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(8) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/01/1971-estudantes-localizam-o-1o-foco-de-ferrugem-do-cafeeiro-em-sao-paulo.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo8 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo8[titulo] = artigo

print(conteudo8)
# Out:
# {'    1971: Estudantes localizam o 1º foco de ferrugem do cafeeiro em São Paulo  ': 'Em uma fazenda em Pedregulho (a cerca de 480 quilômetros ao norte de São Paulo), dois estudantes de agronomia encontraram o primeiro foco da ferrugem do cafeeiro no estado. Uma comitiva de técnicos viajou para o local para realizar os trabalhos de interdição e de isolamento da área afetada pela doença que ataca os cafezais.A estratégia para impedir a propagação da ferrugem envolve toda a região da Alta Mogiana e vai exigir a vistoria em veículos para tentar impedir a transferência de qualquer muda, galho, folha ou fruto do café para outras áreas do estado.      Primeira Página da Folha de 30 janeiro de 1971             - Reprodução'}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(9) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2021/02/1971-se-o-sistema-falhar-astronautas-podem-fazer-passeio-pelo-espaco.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo9 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo9[titulo] = artigo

print(conteudo9)
# Out:
# {"    1971: Se o sistema falhar, astronautas podem fazer 'passeio' pelo espaço  ": 'Os astronautas da Apollo 14 poderão passar do módulo lunar para a nave de comando "caminhando" pelo espaço, na hipótese de o sistema de acoplamento falhar no momento de iniciar a viagem de volta para a Terra.Essa alternativa foi aventada após o mecanismo ter apresentado dificuldade para fazer a junção na ida.O diretor do programa de voos espaciais, Jim McDivitt, diz que os astronautas dispõem de equipamento de socorro, com oxigênio, "cordão umbilical" e outros artefatos, o que possibilita um "passeio" espacial entre as naves. O pouso na Lua está previsto para ocorrer na sexta-feira (5).      Primeira Página da Folha de 3 de fevereiro de 1971             - Reprodução'}

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
#acessando a url fazendo a tratativa do texto(10) e mostrando o conteudo
url = 'https://www1.folha.uol.com.br/banco-de-dados/2020/12/1970-fraude-faz-faculdade-da-santa-casa-de-sao-paulo-anular-o-vestibular.shtml'


response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
html = html.replace('\n', '')

conteudo10 = {}

titulo = (soup.find('h1', class_ = 'c-content-head__title').get_text())
" ".join(html.split()).replace('> <', '><')
titulo = titulo.replace('\n', "")

artigo = (soup.find('div', class_ = 'c-news__body').get_text())
" ".join(html.split()).replace('> <', '><')
artigo = artigo.replace("\n", "")

conteudo10[titulo] = artigo

print(conteudo10)
# Out:
# {'    1970: Fraude faz Faculdade da Santa Casa de São Paulo anular o vestibular  ': 'Com a descoberta da venda de provas e consequente quebra do sigilo das questões, a Faculdade de Ciências Médicas da Santa Casa de Misericórdia, em São Paulo, anulou os dois exames do vestibular, feitos na semana passada, e cancelou o último, que seria realizado no domingo (20).Um funcionário da faculdade confessou, no Deops (Departamento Estadual de Ordem Política e Social de São Paulo), a sua participação no caso.Estudantes suspeitos de terem oferecido dinheiro em troca das questões também estavam sendo interrogados.Estão inscritos no vestibular 2.800 candidatos para disputar 100 vagas.      Primeira Página da Folha de 21 de dezembro de 1970             - Reprodução'}

# %%
import pymongo
from pymongo import MongoClient
#acessando o banco e gravando gravando os textos
myclient = MongoClient('localhost', 27017)
mydb = myclient["avaliacao"]
mycol = mydb["texto"]
mydict = { "texto": conteudo10}
x = mycol.insert_one(mydict)

# %%
def Score_sentimento(frase):
    frase = frase.lower()
    l_sentimento = []
    for p in frase.split():
        l_sentimento.append(int(conteudo1.get(p, 0)))
    score = sum(l_sentimento)
    if score > 0:
        return 'Positivo, Score:{}'.format(score)
    elif score == 0:
        return 'Neutro, Score:{}'.format(score)
    else:
        return 'Negativo, Score:{}'.format(score)

# %%
Score_sentimento('Confederação Brasileira de Desportos) aprovou nesta quarta-feira (4) as diretrizes para a realização do Campeonato Nacional de Futebol Profissional')
# Out:
# 'Neutro, Score:0'

# %%
#importando a biblioteca Spacy
import spacy 
nlp = spacy.load("pt_core_news_sm")

# %%
#puxando o texto
texto1 = "1971: Dom Paulo Evaristo Arns sofre acidente automobilístico em SC  ': 'O arcebispo de São Paulo, dom Paulo Evaristo Arns, teve fratura exposta no tornozelo e escoriações na cabeça, ao sofrer um acidente automobilístico, em Santa Catarina, nesta sexta-feira (14). Segundo os médicos, seu estado de saúde é bom.O carro, que era dirigido pelo irmão marista Antonio Poeing, capotou na rodovia BR-101 após tentar desviar de uma pedra na pista.A mãe de dom Paulo, Helena, e as irmãs dele Zilda e Ida também estavam no automóvel.Eles iam para Forquilhinha, terra natal do arcebispo, para assistir a uma cerimônia religiosa.      Primeira Página da Folha de 15 de maio de 1971             - Reprodução"
doc1 = nlp(texto1)

# %%
doc1
# Out:
# 1971: Dom Paulo Evaristo Arns sofre acidente automobilístico em SC  ': 'O arcebispo de São Paulo, dom Paulo Evaristo Arns, teve fratura exposta no tornozelo e escoriações na cabeça, ao sofrer um acidente automobilístico, em Santa Catarina, nesta sexta-feira (14). Segundo os médicos, seu estado de saúde é bom.O carro, que era dirigido pelo irmão marista Antonio Poeing, capotou na rodovia BR-101 após tentar desviar de uma pedra na pista.A mãe de dom Paulo, Helena, e as irmãs dele Zilda e Ida também estavam no automóvel.Eles iam para Forquilhinha, terra natal do arcebispo, para assistir a uma cerimônia religiosa.      Primeira Página da Folha de 15 de maio de 1971             - Reprodução

# %%
#descobrindo entidades
pers = set(doc1)
for ent in doc1.ents:
    if possible_subject.dep == nsubj and possible_subject.head.pos == PERR:
        perrs.add(possible_subject.head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-483a391986a5> in <module>
#       1 #descobrindo entidades
# ----> 2 pers = set(doc1)
#       3 for ent in doc1.ents:
#       4     if possible_subject.dep == nsubj and possible_subject.head.pos == PERR:
#       5         perrs.add(possible_subject.head)
#
# NameError: name 'doc1' is not defined

# %%
#puxando os verbos
import spacy 
from spacy.symbols import nsubj, VERB
nlp = spacy.load("pt_core_news_sm")
doc = nlp("1971: Dom Paulo Evaristo Arns sofre acidente automobilístico em SC  ': 'O arcebispo de São Paulo, dom Paulo Evaristo Arns, teve fratura exposta no tornozelo e escoriações na cabeça, ao sofrer um acidente automobilístico, em Santa Catarina, nesta sexta-feira (14). Segundo os médicos, seu estado de saúde é bom.O carro, que era dirigido pelo irmão marista Antonio Poeing, capotou na rodovia BR-101 após tentar desviar de uma pedra na pista.A mãe de dom Paulo, Helena, e as irmãs dele Zilda e Ida também estavam no automóvel.Eles iam para Forquilhinha, terra natal do arcebispo, para assistir a uma cerimônia religiosa.      Primeira Página da Folha de 15 de maio de 1971  ")
verbs = set(verbs)
for possible_subject in doc1:
    if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
        verbs.add(possible_subject.head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-52d8ab208142> in <module>
#       4 nlp = spacy.load("pt_core_news_sm")
#       5 doc = nlp("1971: Dom Paulo Evaristo Arns sofre acidente automobilístico em SC  ': 'O arcebispo de São Paulo, dom Paulo Evaristo Arns, teve fratura exposta no tornozelo e escoriações na cabeça, ao sofrer um acidente automobilístico, em Santa Catarina, nesta sexta-feira (14). Segundo os médicos, seu estado de saúde é bom.O carro, que era dirigido pelo irmão marista Antonio Poeing, capotou na rodovia BR-101 após tentar desviar de uma pedra na pista.A mãe de dom Paulo, Helena, e as irmãs dele Zilda e Ida também estavam no automóvel.Eles iam para Forquilhinha, terra natal do arcebispo, para assistir a uma cerimônia religiosa.      Primeira Página da Folha de 15 de maio de 1971  ")
# ----> 6 verbs = set(verbs)
# ...

# %%
[token.lemma_ for token in doc if token.pos_ == 'VERB']
# Out:
# ['sofrer',
#  'ter',
#  'exposto',
#  'sofrer',
#  'dirigir',
#  'capotar',
#  'tentar',
#  'desviar',
#  'ir',
#  'assistir']

# %%
#descobrindo entidades
for ent in doc1.ents:
    print(ent.text, ent.label_)
# Out:
# Dom Paulo MISC
# Evaristo Arns PER
# SC LOC
# arcebispo de São Paulo LOC
# dom Paulo PER
# Evaristo Arns PER
# Santa Catarina LOC
# Antonio Poeing PER
# BR-101 LOC
# dom Paulo PER
# Helena PER
# Zilda PER
# Ida PER
# Forquilhinha LOC

# %%
verbos = ['sofrer','ter','exposto','sofrer','dirigir','capotar','tentar','desviar','ir','assistir']
print(verbos)
# Out:
# ['sofrer', 'ter', 'exposto', 'sofrer', 'dirigir', 'capotar', 'tentar', 'desviar', 'ir', 'assistir']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

with open("C:/Users/joice/dados/texto1.txt", "r", encoding='utf-8') as f:
    artigos = f.read()
# Out:
#   File "<ipython-input-1-60a89dcc4966>", line 4
#     twith open("C:/Users/joice/dados/artigos.txt", "r", encoding='utf-8') as f:
#           ^
# SyntaxError: invalid syntax

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(max_font_size=100,width = 1520, height = 535).generate(artigos)
plt.figure(figsize=(16,9))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
stopwords = set(STOPWORDS)
stopwords.add(['sofrer','ter','exposto','sofrer','dirigir','capotar','tentar','desviar','ir','assistir'])
wordcloud = WordCloud(stopwords=stopwords, background_color="black", width=1600, height=800).generate_from_text(verbos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-705a9065ee09> in <module>
#       1 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#       2 stopwords = set(STOPWORDS)
# ----> 3 stopwords.add(['sofrer','ter','exposto','sofrer','dirigir','capotar','tentar','desviar','ir','assistir'])
#       4 wordcloud = WordCloud(stopwords=stopwords, background_color="black", width=1600, height=800).generate_from_text(verbos)
#       5
#
# TypeError: unhashable type: 'list'

# %%
# %matplotlib inline

from wordcloud import WordCloud

verbos = ' '.join([verbos for verbos in doc1.text_pt])

verbos = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(verbos)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-7fdbbc26f406> in <module>
#       3 from wordcloud import WordCloud
#       4
# ----> 5 verbos = ' '.join([verbos for verbos in doc1.text_pt])
#       6
#       7 verbos = WordCloud(width= 800, height= 500,
#
# AttributeError: 'spacy.tokens.doc.Doc' object has no attribute 'text_pt'

# %%
#tokenização
tokens = [token for token in doc1]
[(token.orth_, token.pos_) for token in doc1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-acb136ad5f52> in <module>
#       5 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#       6 stopwords = set(STOPWORDS)
# ----> 7 stopwords.add(['sofrer','ter','exposto','sofrer','dirigir','capotar','tentar','desviar','ir','assistir'])
#       8 wordcloud = WordCloud(stopwords=stopwords, background_color="black", width=1600, height=800).generate_from_text(tokens)
#       9
#
# TypeError: unhashable type: 'list'

# %%
print()
# Out:
# [1971, :, Dom, Paulo, Evaristo, Arns, sofre, acidente, automobilístico, em, SC,  , ', :, ', O, arcebispo, de, São, Paulo, ,, dom, Paulo, Evaristo, Arns, ,, teve, fratura, exposta, no, tornozelo, e, escoriações, na, cabeça, ,, ao, sofrer, um, acidente, automobilístico, ,, em, Santa, Catarina, ,, nesta, sexta-feira, (, 14, ), ., Segundo, os, médicos, ,, seu, estado, de, saúde, é, bom, ., O, carro, ,, que, era, dirigido, pelo, irmão, marista, Antonio, Poeing, ,, capotou, na, rodovia, BR-101, após, tentar, desviar, de, uma, pedra, na, pista, ., A, mãe, de, dom, Paulo, ,, Helena, ,, e, as, irmãs, dele, Zilda, e, Ida, também, estavam, no, automóvel, ., Eles, iam, para, Forquilhinha, ,, terra, natal, do, arcebispo, ,, para, assistir, a, uma, cerimônia, religiosa, .,      , Primeira, Página, da, Folha, de, 15, de, maio, de, 1971,             , -, Reprodução]

# %%
# %matplotlib inline

from wordcloud import WordCloud
tokens = ' '.join([texto for texto in tokens.text_pt])

tokens = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-114c607ac0ee> in <module>
#       2
#       3 from wordcloud import WordCloud
# ----> 4 tokens = ' '.join([texto for texto in tokens.text_pt])
#       5
#       6 tokens = WordCloud(width= 800, height= 500,
#
# NameError: name 'tokens' is not defined

# %%
for token in doc1:
    print(token.text, "-->", token.dep_)
# Out:
# 1971 --> ROOT
# : --> punct
# Dom --> appos
# Paulo --> flat:name
# Evaristo --> flat:name
# Arns --> flat:name
# sofre --> parataxis
# acidente --> obj
# automobilístico --> amod
# em --> case
# SC --> obl
#   --> flat:name
# ' --> punct
# : --> punct
# ' --> punct
# O --> det
# arcebispo --> nsubj
# de --> case
# São --> nmod
# Paulo --> flat:name
# , --> punct
# dom --> dep
# Paulo --> nsubj
# Evaristo --> flat:name
# Arns --> flat:name
# , --> punct
# teve --> parataxis
# fratura --> obj
# exposta --> acl
# no --> case
# tornozelo --> obl
# e --> cc
# escoriações --> conj
# na --> case
# cabeça --> obl
# , --> punct
# ao --> mark
# sofrer --> advcl
# um --> det
# acidente --> obj
# automobilístico --> amod
# , --> punct
# em --> case
# Santa --> obl
# Catarina --> flat:name
# , --> punct
# nesta --> case
# sexta-feira --> obl
# ( --> punct
# 14 --> obl
# ) --> punct
# . --> punct
# Segundo --> case
# os --> det
# médicos --> obl
# , --> punct
# seu --> det
# estado --> nsubj
# ...

# %%
spacy.explain("nsubj"), spacy.explain("ROOT"), spacy.explain("aux"), spacy.explain("advcl"), spacy.explain("dobj")
# Out:
# ('nominal subject',
#  None,
#  'auxiliary',
#  'adverbial clause modifier',
#  'direct object')

# %%
from spacy import displacy
texto = nlp("1971: Dom Paulo Evaristo Arns sofre acidente automobilístico em SC  ': 'O arcebispo de São Paulo, dom Paulo Evaristo Arns, teve fratura exposta no tornozelo e escoriações na cabeça, ao sofrer um acidente automobilístico, em Santa Catarina, nesta sexta-feira (14). Segundo os médicos, seu estado de saúde é bom.O carro, que era dirigido pelo irmão marista Antonio Poeing, capotou na rodovia BR-101 após tentar desviar de uma pedra na pista.A mãe de dom Paulo, Helena, e as irmãs dele Zilda e Ida também estavam no automóvel.Eles iam para Forquilhinha, terra natal do arcebispo, para assistir a uma cerimônia religiosa.      Primeira Página da Folha de 15 de maio de 1971             - Reprodução")
displacy.render(texto, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1971:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dom Paulo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Evaristo Arns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  sofre acidente automobilístico em
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SC
# ...

# %%
def Score_sentimento(frase):
    frase = frase.lower()
    l_sentimento = []
    for p in frase.split():
        l_sentimento.append(int(conteudo.get(p, 0)))
    score = sum(l_sentimento)
    if score > 0:
        return 'Positivo, Score:{}'.format(score)
    elif score == 0:
        return 'Neutro, Score:{}'.format(score)
    else:
        return 'Negativo, Score:{}'.format(score)

# %%
Score_sentimento('')
# Out:
# 'Neutro, Score:0'

# %%
# %matplotlib inline

from wordcloud import WordCloud

= ' '.join([texto for texto in resenha.text_pt])

nuvem_palvras = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(todas_palavras)
